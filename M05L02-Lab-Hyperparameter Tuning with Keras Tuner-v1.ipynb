# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Hyperparameter Tuning with Keras Tuner**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will learn how to set up Keras Tuner and prepare the environment for hyperparameter tuning.
#
# ## Learning objectives:
# By the end of this lab, you will:
# - Install Keras Tuner and import the necessary libraries
# - Load and preprocess the MNIST data set
# - Define a model-building function that uses hyperparameters to configure the model architecture
# - Set up Keras Tuner to search for the best hyperparameter configuration
# - Retrieve the best hyperparameters from the search and build a model with these optimized values
#
# ## Prerequisites:
# - Basic understanding of Python programming
# - Keras and TensorFlow installed

# %% [markdown]
# ### Exercise 1: Install the Keras Tuner
#
# This exercise guides you through the initial setup for using Keras Tuner. You install the library, import necessary modules, and load and preprocess the MNIST data set, which will be used for hyperparameter tuning.
# 1. **Install Keras Tuner:**
#     - Use pip to install Keras Tuner
# 2. **Import necessary libraries:**
#     - Import Keras Tuner, TensorFlow, and Keras modules
# 3. **Load and preprocess the MNIST data set:**
#     - Load the MNIST data set.
#     - Normalize the data set by dividing by 255.0.

# %%
# !pip install tensorflow==2.16.2
# !pip install keras-tuner==1.4.7
# !pip install numpy<2.0.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.16.2 (from versions: 2.20.0rc0, 2.20.0, 2.21.0rc0)
# ERROR: No matching distribution found for tensorflow==2.16.2
# Collecting keras-tuner==1.4.7
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner==1.4.7) (3.13.2)
# Requirement already satisfied: packaging in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner==1.4.7) (25.0)
# Requirement already satisfied: requests in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner==1.4.7) (2.32.5)
# Requirement already satisfied: kt-legacy in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner==1.4.7) (1.0.5)
# Requirement already satisfied: absl-py in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (2.4.0)
# Requirement already satisfied: numpy in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (2.3.4)
# Requirement already satisfied: rich in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (14.0.0)
# Requirement already satisfied: namex in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (0.1.0)
# Requirement already satisfied: h5py in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (3.15.1)
# Requirement already satisfied: optree in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (0.18.0)
# Requirement already satisfied: ml-dtypes in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner==1.4.7) (0.5.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\anaconda3\envs\ds\lib\site-packages (from optree->keras->keras-tuner==1.4.7) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner==1.4.7) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner==1.4.7) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner==1.4.7) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner==1.4.7) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\envs\ds\lib\site-packages (from rich->keras->keras-tuner==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\envs\ds\lib\site-packages (from rich->keras->keras-tuner==1.4.7) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\envs\ds\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner==1.4.7) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
# Installing collected packages: keras-tuner
#   Attempting uninstall: keras-tuner
#     Found existing installation: keras-tuner 1.4.8
#     Uninstalling keras-tuner-1.4.8:
#       Successfully uninstalled keras-tuner-1.4.8
# Successfully installed keras-tuner-1.4.7
# ϵͳ�Ҳ���ָ�����ļ���

# %% [markdown]
# #### Explanation:
# This code installs the necessary libraries using pip
#
# - **TensorFlow**: Ensures compatibility with the Keras Tuner.
# - **Keras Tuner**: The version used in this lab.
# - **Numpy**: Ensures compatibility with the other installed packages.

# %%
import sys

# Increase recursion limit to prevent potential issues
sys.setrecursionlimit(100000)

# %% [markdown]
# #### Explanation:
# The sys.setrecursionlimit function is used to increase the recursion limit, which helps prevent potential recursion errors when running complex models with deep nested functions or when using certain libraries like TensorFlow.

# %%
# Step 2: Import necessary libraries
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
import os
import warnings

# Suppress all Python warnings
warnings.filterwarnings('ignore')

# Set TensorFlow log level to suppress warnings and info messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0 = all logs, 1 = filter out INFO, 2 = filter out INFO and WARNING, 3 = ERROR only

# %%
# !pip install scikit-learn
from tensorflow import keras
from sklearn.model_selection import train_test_split

# Load the MNIST dataset
(x_all, y_all), _ = keras.datasets.mnist.load_data()

# Flatten and normalize the images
x_all = x_all.reshape((x_all.shape[0], -1)).astype("float32") / 255.0

# Split into train+val and test (80/20)
x_temp, x_test, y_temp, y_test = train_test_split(x_all, y_all, test_size=0.2, random_state=42)

# Split train+val into train and validation (75/25 of 80% = 60/20 overall)
x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size=0.25, random_state=42)
# Out:
# Requirement already satisfied: scikit-learn in d:\anaconda3\envs\ds\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in d:\anaconda3\envs\ds\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in d:\anaconda3\envs\ds\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\envs\ds\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\envs\ds\lib\site-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# #### Explanation
#
# This code imports the necessary libraries:
#
# - **`keras_tuner`**: Used for hyperparameter tuning.
# - **`Sequential`**: A linear stack of layers in Keras.
# - **`Dense`**, **`Flatten`**: Common Keras layers.
# - **`mnist`**: The MNIST dataset, a standard dataset for image classification.
# - **`Adam`**: An optimizer in Keras.

# %%
# Step 3: Load and preprocess the MNIST dataset
(x_train, y_train), (x_val, y_val) = mnist.load_data()
x_train, x_val = x_train / 255.0, x_val / 255.0

print(f'Training data shape: {x_train.shape}')
print(f'Validation data shape: {x_val.shape}')
# Out:
# Training data shape: (60000, 28, 28)
# Validation data shape: (10000, 28, 28)

# %% [markdown]
# #### Explanation
#
# This code loads the MNIST dataset and preprocesses it:
#
# - **`mnist.load_data()`**: Loads the dataset, returning training and validation splits.
# - **`x_train / 255.0`**: Normalizes the pixel values to be between 0 and 1.
# - **`print(f'...')`**: Displays the shapes of the training and validation datasets.

# %% [markdown]
# ### Exercise 2: Defining the model with hyperparameters
#
# In this exercise, you define a model-building function that uses the `HyperParameters` object to specify the number of units in a dense layer and the learning rate. This function returns a compiled Keras model that is ready for hyperparameter tuning.
#
# **Define a model-building function:**
# - Create a function `build_model` that takes a `HyperParameters` object as input.
# - Use the `HyperParameters` object to define the number of units in a dense layer and the learning rate for the optimizer.
# - Compile the model with sparse categorical cross-entropy loss and Adam optimizer.

# %%
# Define a model-building function 

def build_model(hp):
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# #### Explanation
#
# This function builds and compiles a Keras model with hyperparameters:
#
# - **`hp.Int('units', ...)`**: Defines the number of units in the Dense layer as a hyperparameter.
# - **`hp.Float('learning_rate', ...)`**: Defines the learning rate as a hyperparameter.
# - **`model.compile()`**: Compiles the model with the Adam optimizer and sparse categorical cross-entropy loss.

# %% [markdown]
# ### Exercise 3: Configuring the hyperparameter search
#
# This exercise guides you through configuring Keras Tuner. You create a `RandomSearch` tuner, specifying the model-building function, the optimization objective, the number of trials, and the directory for storing results. The search space summary provides an overview of the hyperparameters being tuned.
#
# **Create a RandomSearch Tuner:**
# - Use the `RandomSearch` class from Keras Tuner.
# - Specify the model-building function, optimization objective (validation accuracy), number of trials, and directory for storing results.

# %%
# Create a RandomSearch Tuner 

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='intro_to_kt'
)

# Display a summary of the search space 
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %% [markdown]
# #### Explanation
#
# This code sets up a Keras Tuner `RandomSearch`:
#
# - **`build_model`**: The model-building function.
# - **`objective='val_accuracy'`**: The metric to optimize (validation accuracy).
# - **`max_trials=10`**: The maximum number of different hyperparameter configurations to try.
# - **`executions_per_trial=2`**: The number of times to run each configuration.
# - **`directory='my_dir'`**: Directory to save the results.
# - **`project_name='intro_to_kt'`**: Name of the project for organizing results.
#
# Displays a summary of the hyperparameter search space, providing an overview of the hyperparameters being tuned.

# %% [markdown]
# ### Exercise 4: Running the hyperparameter search
#
# In this exercise, you run the hyperparameter search using the `search` method of the tuner. You provide the training and validation data along with the number of epochs. After the search is complete, the results summary displays the best hyperparameter configurations found.
#
# **Run the search:**
# - Use the `search` method of the tuner.
# - Pass in the training data, validation data, and the number of epochs

# %%
# Run the hyperparameter search 
tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val)) 

# Display a summary of the results 
tuner.results_summary()
# Out:
# Trial 10 Complete [00h 01m 26s]
# val_accuracy: 0.9678000211715698
#
# Best val_accuracy So Far: 0.9802500009536743
# Total elapsed time: 00h 08m 49s
# Results summary
# Results in my_dir\intro_to_kt
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 03 summary
# Hyperparameters:
# units: 480
# learning_rate: 0.0012076098541628248
# Score: 0.9802500009536743
#
# Trial 04 summary
# Hyperparameters:
# units: 320
# learning_rate: 0.0006374631226478013
# Score: 0.9783499836921692
#
# Trial 00 summary
# Hyperparameters:
# units: 96
# learning_rate: 0.0013812005903276895
# Score: 0.9767500162124634
#
# Trial 01 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.0007017469625198215
# Score: 0.970550000667572
#
# Trial 08 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.0006011330383467168
# Score: 0.9701000154018402
#
# Trial 05 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.0005144475412729949
# Score: 0.9700499773025513
#
# Trial 09 summary
# Hyperparameters:
# units: 416
# learning_rate: 0.00011420289343998813
# Score: 0.9678000211715698
#
# Trial 02 summary
# Hyperparameters:
# units: 96
# learning_rate: 0.00028636418591913084
# Score: 0.9673500061035156
#
# Trial 07 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.00471399662441768
# Score: 0.9670000076293945
#
# Trial 06 summary
# Hyperparameters:
# units: 32
# learning_rate: 0.00010948067065592716
# Score: 0.9301500022411346

# %% [markdown]
# #### Explanation
#
# This command runs the hyperparameter search:
#
# - **`epochs=5`**: Each trial is trained for 5 epochs.
# - **`validation_data=(x_val, y_val)`**: The validation data to evaluate the model's performance during the search.
#
# After the search is complete, this command displays a summary of the best hyperparameter configurations found during the search.

# %% [markdown]
# ## Exercise 5: Analyzing and using the best hyperparameters
#
# In this exercise, you retrieve the best hyperparameters found during the search and print their values. You then build a model with these optimized hyperparameters and train it on the full training data set. Finally, you evaluate the model’s performance on the test set to ensure that it performs well with the selected hyperparameters.
#
# **Retrieve the best hyperparameters:**
# - Use the `get_best_hyperparameters` method to get the best hyperparameters.
# - Print the optimal values for the hyperparameters.
#
# **Build and train the model:**
# - Build a model using the best hyperparameters.
# - Train the model on the full training data set and evaluate its performance on the test set.

# %%
# Step 1: Retrieve the best hyperparameters 

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0] 
print(f""" 

The optimal number of units in the first dense layer is {best_hps.get('units')}. 

The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}. 

""") 

# Step 2: Build and Train the Model with Best Hyperparameters 
model = tuner.hypermodel.build(best_hps) 
model.fit(x_train, y_train, epochs=10, validation_split=0.2) 

# Evaluate the model on the test set 
test_loss, test_acc = model.evaluate(x_val, y_val) 
print(f'Test accuracy: {test_acc}')
# Out:
#
#
# The optimal number of units in the first dense layer is 480.
#
# The optimal learning rate for the optimizer is 0.0012076098541628248.
#
#
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9361 - loss: 0.2185 - val_accuracy: 0.9670 - val_loss: 0.1130
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9734 - loss: 0.0861 - val_accuracy: 0.9751 - val_loss: 0.0824
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9829 - loss: 0.0557 - val_accuracy: 0.9708 - val_loss: 0.0910
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9871 - loss: 0.0391 - val_accuracy: 0.9747 - val_loss: 0.0898
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9906 - loss: 0.0293 - val_accuracy: 0.9778 - val_loss: 0.0807
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9927 - loss: 0.0226 - val_accuracy: 0.9725 - val_loss: 0.1108
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9940 - loss: 0.0177 - val_accuracy: 0.9762 - val_loss: 0.0949
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9940 - loss: 0.0171 - val_accuracy: 0.9783 - val_loss: 0.0932
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9959 - loss: 0.0123 - val_accuracy: 0.9776 - val_loss: 0.1027
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9948 - loss: 0.0153 - val_accuracy: 0.9768 - val_loss: 0.1100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9756 - loss: 0.1068
# Test accuracy: 0.975600004196167

# %% [markdown]
# #### Explanation
#
# This code retrieves the best hyperparameters found during the search:
#
# - **`get_best_hyperparameters(num_trials=1)`**: Gets the best hyperparameter configuration.
# - **`print(f"...")`**: Prints the best hyperparameters.
# - **`model.fit(...)`**: Trains the model on the full training data with a validation split of 20%.
# - **`model.evaluate(...)`**: Evaluates the model on the test (validation) dataset and prints the accuracy, which gives an indication of how well the model generalizes.

# %% [markdown]
# ## Practice exercises
#
# ### Exercise 1: Setting Up Keras Tuner
#
# #### Objective:
# Learn how to set up Keras Tuner and prepare the environment for hyperparameter tuning.
#
# #### Instructions:
# 1. Install Keras Tuner.
# 2. Import necessary libraries.
# 3. Load and preprocess the MNIST data set.

# %%
# Write your code here
# !pip install keras-tuner 

# Step 2: Import necessary libraries 
import keras_tuner as kt 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Flatten 
from tensorflow.keras.datasets import mnist 
from tensorflow.keras.optimizers import Adam 

# Step 3: Load and preprocess the MNIST data set 
(x_train, y_train), (x_val, y_val) = mnist.load_data() 
x_train, x_val = x_train / 255.0, x_val / 255.0 

# Print the shapes of the training and validation datasets
print(f'Training data shape: {x_train.shape}') 
print(f'Validation data shape: {x_val.shape}')
# Out:
# Requirement already satisfied: keras-tuner in d:\anaconda3\envs\ds\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner) (3.13.2)
# Requirement already satisfied: packaging in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner) (25.0)
# Requirement already satisfied: requests in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner) (2.32.5)
# Requirement already satisfied: kt-legacy in d:\anaconda3\envs\ds\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (2.4.0)
# Requirement already satisfied: numpy in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (2.3.4)
# Requirement already satisfied: rich in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (14.0.0)
# Requirement already satisfied: namex in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (3.15.1)
# Requirement already satisfied: optree in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (0.18.0)
# Requirement already satisfied: ml-dtypes in d:\anaconda3\envs\ds\lib\site-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\anaconda3\envs\ds\lib\site-packages (from optree->keras->keras-tuner) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\ds\lib\site-packages (from requests->keras-tuner) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\envs\ds\lib\site-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\envs\ds\lib\site-packages (from rich->keras->keras-tuner) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\envs\ds\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Training data shape: (60000, 28, 28)
# Validation data shape: (10000, 28, 28)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# !pip install keras-tuner
#
# # Step 2: Import necessary libraries
# import keras_tuner as kt
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten
# from tensorflow.keras.datasets import mnist
# from tensorflow.keras.optimizers import Adam
#
# # Step 3: Load and preprocess the MNIST data set
# (x_train, y_train), (x_val, y_val) = mnist.load_data()
# x_train, x_val = x_train / 255.0, x_val / 255.0
#
# # Print the shapes of the training and validation datasets
# print(f'Training data shape: {x_train.shape}')
# print(f'Validation data shape: {x_val.shape}')
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2: Defining the model with hyperparameters
#
# #### Objective:
# Define a model-building function that uses hyperparameters to configure the model architecture.
#
# #### Instructions:
# 1. Define a model-building function that uses the `HyperParameters` object to specify the number of units in a dense layer and the learning rate.
# 2. Compile the model with sparse categorical cross-entropy loss and Adam optimizer.

# %%
# Write your code here
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt

# Step 1: Define a model-building function
def build_model(hp):
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten
# from tensorflow.keras.optimizers import Adam
# import keras_tuner as kt
#
# # Step 1: Define a model-building function
# def build_model(hp):
#     model = Sequential([
#         Flatten(input_shape=(28, 28)),
#         Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'),
#         Dense(10, activation='softmax')
#     ])
#
#     model.compile(
#         optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
#         loss='sparse_categorical_crossentropy',
#         metrics=['accuracy']
#     )
#
#     return model
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3: Configuring the hyperparameter search
#
# #### Objective:
# Set up Keras Tuner to search for the best hyperparameter configuration.
#
# #### Instructions:
# 1. Create a `RandomSearch` tuner using the model-building function.
# 2. Specify the optimization objective, number of trials, and directory for storing results.

# %%
# Write your code here
import keras_tuner as kt

# Step 1: Create a RandomSearch Tuner
tuner = kt.RandomSearch(
    build_model,  # Ensure 'build_model' function is defined from previous code
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='intro_to_kt'
)

# Display a summary of the search space
tuner.search_space_summary()
# Out:
# Reloading Tuner from my_dir\intro_to_kt\tuner0.json
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# import keras_tuner as kt
#
# # Step 1: Create a RandomSearch Tuner
# tuner = kt.RandomSearch(
#     build_model,  # Ensure 'build_model' function is defined from previous code
#     objective='val_accuracy',
#     max_trials=10,
#     executions_per_trial=2,
#     directory='my_dir',
#     project_name='intro_to_kt'
# )
#
# # Display a summary of the search space
# tuner.search_space_summary()
# ```
#
# </details>

# %% [markdown]
# ### Exercise 4: Running the hyperparameter search
#
# #### Objective:
# Run the hyperparameter search and dispaly the summary of the results.
#
# #### Instructions:
# 1. Run the hyperparameter search using the `search` method of the tuner.
# 2. Pass in the training data, validation data, and the number of epochs.
# 3. Display a summary of the results.

# %%
# Write your code here
# Step 1: Run the hyperparameter search 

tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val)) 

 # Display a summary of the results 

tuner.results_summary()
# Out:
# Results summary
# Results in my_dir\intro_to_kt
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 03 summary
# Hyperparameters:
# units: 480
# learning_rate: 0.0012076098541628248
# Score: 0.9802500009536743
#
# Trial 04 summary
# Hyperparameters:
# units: 320
# learning_rate: 0.0006374631226478013
# Score: 0.9783499836921692
#
# Trial 00 summary
# Hyperparameters:
# units: 96
# learning_rate: 0.0013812005903276895
# Score: 0.9767500162124634
#
# Trial 01 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.0007017469625198215
# Score: 0.970550000667572
#
# Trial 08 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.0006011330383467168
# Score: 0.9701000154018402
#
# Trial 05 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.0005144475412729949
# Score: 0.9700499773025513
#
# Trial 09 summary
# Hyperparameters:
# units: 416
# learning_rate: 0.00011420289343998813
# Score: 0.9678000211715698
#
# Trial 02 summary
# Hyperparameters:
# units: 96
# learning_rate: 0.00028636418591913084
# Score: 0.9673500061035156
#
# Trial 07 summary
# Hyperparameters:
# units: 64
# learning_rate: 0.00471399662441768
# Score: 0.9670000076293945
#
# Trial 06 summary
# Hyperparameters:
# units: 32
# learning_rate: 0.00010948067065592716
# Score: 0.9301500022411346

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# # Step 1: Run the hyperparameter search
#
# tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
#
#  # Display a summary of the results
#
# tuner.results_summary()
# ```
#
# </details>

# %% [markdown]
# ### Exercise 5: Analyzing and using the best hyperparameters
#
# #### Objective:
# Retrieve the best hyperparameters from the search and build a model with these optimized values.
#
# #### Instructions:
# 1. Retrieve the best hyperparameters using the `get_best_hyperparameters` method.
# 2. Build a model using the best hyperparameters.
# 3. Train the model on the full training data set and evaluate its performance on the validation set.

# %%
# Write your code here
# Step 1: Retrieve the best hyperparameters 

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0] 

print(f""" 

The optimal number of units in the first dense layer is {best_hps.get('units')}. 

The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}. 

""") 

 # Step 2: Build and train the model with best hyperparameters 

model = tuner.hypermodel.build(best_hps) 

model.fit(x_train, y_train, epochs=10, validation_split=0.2) 

 # Evaluate the model on the validation set 

val_loss, val_acc = model.evaluate(x_val, y_val) 

print(f'Validation accuracy: {val_acc}')
# Out:
#
#
# The optimal number of units in the first dense layer is 480.
#
# The optimal learning rate for the optimizer is 0.0012076098541628248.
#
#
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9359 - loss: 0.2152 - val_accuracy: 0.9643 - val_loss: 0.1163
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9732 - loss: 0.0865 - val_accuracy: 0.9698 - val_loss: 0.0999
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9824 - loss: 0.0553 - val_accuracy: 0.9734 - val_loss: 0.0901
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9874 - loss: 0.0396 - val_accuracy: 0.9761 - val_loss: 0.0834
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9897 - loss: 0.0298 - val_accuracy: 0.9708 - val_loss: 0.1105
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9933 - loss: 0.0214 - val_accuracy: 0.9755 - val_loss: 0.0940
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9941 - loss: 0.0188 - val_accuracy: 0.9747 - val_loss: 0.1046
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.9793 - val_loss: 0.0869
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9777 - val_loss: 0.1026
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9964 - loss: 0.0111 - val_accuracy: 0.9793 - val_loss: 0.1000
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9798 - loss: 0.0925
# Validation accuracy: 0.9797999858856201

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# # Step 1: Retrieve the best hyperparameters
#
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# print(f"""
#
# The optimal number of units in the first dense layer is {best_hps.get('units')}.
#
# The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
#
# """)
#
#  # Step 2: Build and train the model with best hyperparameters
#
# model = tuner.hypermodel.build(best_hps)
#
# model.fit(x_train, y_train, epochs=10, validation_split=0.2)
#
#  # Evaluate the model on the validation set
#
# val_loss, val_acc = model.evaluate(x_val, y_val)
#
# print(f'Validation accuracy: {val_acc}')
# ```
#
# </details>

# %% [markdown]
# ### Conclusion
#
# Congratulations on completing this lab! You have learned to set up Keras Tuner and prepare the environment for hyperparameter tuning. In addition, you defined a model-building function that uses hyperparameters to configure the model architecture. You configured Keras Tuner to search for the best hyperparameter configuration and learned to run the hyperparameter search and analyze the results. Finally, you retrieved the best hyperparameters and built a model with these optimized values.

# %% [markdown]
# ## Authors

# %% [markdown]
# Skillup

# %% [markdown]
# Copyright ©IBM Corporation. All rights reserved.
